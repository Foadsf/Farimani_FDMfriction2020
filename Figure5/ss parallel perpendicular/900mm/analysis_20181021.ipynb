# %%
import os
os.chdir(os.getcwd())

import pandas as pd
import numpy as np

from scipy.optimize import curve_fit

# %%
speed=[50,100,150,200,300,400,600,800,1000,1200,1400,1600,1800]


def func_2(x,a,b):
    return a*x**(2/3.0)+b*x
# static_force , max_mean
df6=pd.DataFrame(columns=['a','b'],index=speed)
for i,s in enumerate(speed):
    df5=pd.read_excel('analysis.xlsx', sheet_name=str(s))
    popt, pcov = curve_fit(func_2, df5.index.values.astype(float)*9.81/1000, df5['max_mean'].values.astype(float))
    df6['a'][s]=popt[0]
    df6['b'][s]=popt[1]
df6
# Out:
#               a           b
# 50     0.171142    0.109222
# 100    0.164175    0.137248
# 150    0.171142    0.109222
# 200     0.23114   0.0599655
# 300   0.0556227    0.204208
# 400    0.177451   0.0862311
# 600    0.168042    0.071291
# 800    0.222877 -0.00563625
# 1000   0.180044   0.0280354
# 1200   0.158228   0.0546079
# 1400   0.218144  0.00247035
# 1600   0.219267 -0.00159792
# 1800   0.202709   0.0128099
